# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 660.6 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/61.0 kB 660.6 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.0 kB 219.4 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 325.6 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB 435.7 kB/s eta 0:00:27
#    ---------------------------------------- 0.0/11.6 MB 435.7 kB/s eta 0:00:27
#    ---------------------------------------- 0.0/11.6 MB 435.7 kB/s eta 0:00:27
#    ---------------------------------------- 0.1/11.6 MB 357.2 kB/s eta 0:00:33
#    ---------------------------------------- 0.1/11.6 MB 504.4 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/11.6 MB 504.4 kB/s eta 0:00:23
# ...

# %%
pip install pandas
# Out:
# ...
#
#   Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl (11.6 MB)
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {'שם': ['אליז', 'בת שבע', 'גליה'],
        'ממוצע ציונים': [25, 32, 18],
        'כיתה': ['ג', 'ב', 'א']}

# %%
sample = pd.DataFrame(data)
sample
# Out:
#        שם  ממוצע ציונים כיתה
# 0    אליז            25    ג
# 1  בת שבע            32    ב
# 2    גליה            18    א

# %%
sample[sample['כיתה'] == 'א']
# Out:
#      שם  ממוצע ציונים כיתה
# 2  גליה            18    א

# %%
onecole =sample.read_csv(sample, usecols=['שם'])
onecole
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4892\3340381126.py in ?()
# ----> 1 onecole =sample.read_csv(sample, usecols=['שם'])
#       2 onecole
#
# C:\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
sample[sample["כיתה"]=="ג"]
# Out:
#      שם ממוצע ציונים כיתה  ג  ב  א מיכל
# 0  אליז           25    ג  ג  ג  ג    ג

# %%
sample.loc[len(sample.index)]=["ג","90","ר"]
sample
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 sample.loc[len(sample.index)]=["ג","90","ר"]
#       2 sample
#
# File C:\Python310\lib\site-packages\pandas\core\indexing.py:912, in _LocationIndexer.__setitem__(self, key, value)
#     909 self._has_valid_setitem_indexer(key)
#     911 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 912 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\Python310\lib\site-packages\pandas\core\indexing.py:1936, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1933     indexer, missing = convert_missing_indexer(indexer)
#    1935     if missing:
# -> 1936         self._setitem_with_indexer_missing(indexer, value)
#    1937         return
#    1939 if name == "loc":
#    1940     # must come after setting of missing
#
# ...

# %%
data = {'שם': ['אליז', 'בת שבע', 'גליה'],
        'ממוצע ציונים': [25, 32, 18],
        'כיתה': ['ג', 'ב', 'א']}

# %%
sample = pd.DataFrame(data)
sample
# Out:
#        שם  ממוצע ציונים כיתה
# 0    אליז            25    ג
# 1  בת שבע            32    ב
# 2    גליה            18    א

# %%
sample[sample['כיתה'] == 'א']
# Out:
#      שם  ממוצע ציונים כיתה
# 2  גליה            18    א

# %%
sample[sample["כיתה"]=="ג"]
# Out:
#      שם  ממוצע ציונים כיתה
# 0  אליז            25    ג

# %%
sample.loc[len(sample.index)]=["ג",90,"ר"]
sample
# Out:
#        שם ממוצע ציונים כיתה
# 0    אליז           25    ג
# 1  בת שבע           32    ב
# 2    גליה           18    א
# 3       ג           90    ר

# %%
sample = pd.DataFrame(data)
sample
# Out:
#        שם  ממוצע ציונים כיתה
# 0    אליז            25    ג
# 1  בת שבע            32    ב
# 2    גליה            18    א

# %%
sample['ממוצע ציונים'].max()
# Out:
# 32

# %%
df = pd.read_csv("Z:\B\צדוק מיכל\פיתון מתקדם\lesson6\cities.csv")
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      99       35       59   "N"      120       77       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df.isnull().sum()
# Out:
# LatD        0
#  "LatM"     0
#  "LatS"     0
#  "NS"       0
#  "LonD"     0
#  "LonM"     0
#  "LonS"     0
#  "EW"       0
#  "City"     0
#  "State"    0
# dtype: int64

# %%
df.LonM = df.LonM.fillna(7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4892\3041629060.py in ?()
# ----> 1 df.LonM = df.LonM.fillna(7)
#
# C:\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'LonM'

# %%
df.LatS = df.LatS.fillna("other")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4892\2107152129.py in ?()
# ----> 1 df.LatS = df.LatS.fillna("other")
#
# C:\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'LatS'

# %%
med = df.LatS.median()
df.LatS = df.LatS.fillna(med)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4892\1643315414.py in ?()
# ----> 1 med = df.LatS.median()
#       2 df.LatS = df.LatS.fillna(med)
#
# C:\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'LatS'

# %%
med = df.LatD.median()
df.LatD = df.LatD.fillna(med)

# %%
df.columns=df.columns.str.strip()

# %%
df.drop_duplicates()
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      99       35       59   "N"      120       77       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df['LatD'].mean()
# Out:
# 39.234375

# %%
df['LatD'].max()
# Out:
# 99

# %%
df['LatD'].min()
# Out:
# 26

# %%
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      99       35       59   "N"      120       77       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df['sub']=df.LatD/df.LatD

# %%
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      99       35       59   "N"      120       77       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"  sub
# 0          "Youngstown"       OH  1.0
# 1             "Yankton"       SD  1.0
# 2              "Yakima"       WA  1.0
# ...

# %%
df.rename(columns={'LatD': 'Population'}, inplace=True)

# %%
df
# Out:
#      Population   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0            41        5       59   "N"       80       39        0   "W"
# 1            42       52       48   "N"       97       23       23   "W"
# 2            99       35       59   "N"      120       77       36   "W"
# 3            42       16       12   "N"       71       48        0   "W"
# 4            43       37       48   "N"       89       46       11   "W"
# ..          ...      ...      ...   ...      ...      ...      ...   ...
# 123          39       31       12   "N"      119       48       35   "W"
# 124          50       25       11   "N"      104       39        0   "W"
# 125          40       10       48   "N"      122       14       23   "W"
# 126          40       19       48   "N"       75       55       48   "W"
# 127          41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"  sub
# 0          "Youngstown"       OH  1.0
# ...

# %%
df.loc[df.Population==41]
# Out:
#      Population   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0            41        5       59   "N"       80       39        0   "W"
# 11           41       15        0   "N"       77        0        0   "W"
# 18           41       25       11   "N"      122       23       23   "W"
# 25           41       32       59   "N"       73        3        0   "W"
# 27           41       50       59   "N"       79        8       23   "W"
# 49           41       39        0   "N"       83       32       24   "W"
# 69           41       40       48   "N"       86       15        0   "W"
# 79           41       24       35   "N"       75       40       11   "W"
# 80           41       52       11   "N"      103       39       36   "W"
# 91           41       27        0   "N"       82       42       35   "W"
# 114          41       35       24   "N"      109       13       48   "W"
# 127          41        9       35   "N"       81       14       23   "W"
#
# ...

# %%
df.sort_values('Population', ascending=False)
# Out:
#      Population   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 2            99       35       59   "N"      120       77       36   "W"
# 124          50       25       11   "N"      104       39        0   "W"
# 33           49       16       12   "N"      123        7       12   "W"
# 6            49       52       99   "N"       97        9        0   "W"
# 10           48        9        0   "N"      103       37       12   "W"
# ..          ...      ...      ...   ...      ...      ...      ...   ...
# 108          29       53       23   "N"       81       19       11   "W"
# 31           28       48       35   "N"       97        0       36   "W"
# 84           27       20       24   "N"       82       31       47   "W"
# 52           27       57        0   "N"       82       26       59   "W"
# 16           26       43       11   "N"       80        3       99   "W"
#
#                  "City"  "State"  sub
# 2              "Yakima"       WA  1.0
# ...
